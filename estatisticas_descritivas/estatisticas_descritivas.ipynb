# %% [markdown]
# **D1DAE: Análise Estatística para Ciência de Dados** <br/>
# IFSP Campinas
#
# Prof. Dr. Samuel Martins (Samuka) <br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# #### Custom CSS style

# %%
# %%html
# <style>.dashed-box{border:1px dashed #000!important}.dashed-box tr{background-color:#fff!important}.alt-tab{background-color:#000;color:#ffc351;padding:4px;font-size:1em;font-weight:700;font-family:monospace}</style>
# Out:
# <style>.dashed-box{border:1px dashed #000!important}.dashed-box tr{background-color:#fff!important}.alt-tab{background-color:#000;color:#ffc351;padding:4px;font-size:1em;font-weight:700;font-family:monospace}</style>

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
# pacotes usados neste notebook
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>Estatística Descritiva</h1><hr/>

# %% [markdown]
# <h2>1. Problema e Dataset</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *observação (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.

# %% [markdown]
# <table align="left" class='dashed-box'>
# <tr>
#     <td>💡</td>
#     <td>O dataset utilizado neste notebook já foi _pré-processado_ anteriormente. Para mais informações, cheque os vídeos mostrados do curso <a href="https://www.youtube.com/playlist?list=PL3ZslI15yo2pfkf7EGNR14xTwe-wZ2bNX">"Pandas Essencial" no YouTube</a>, onde realizamos tal preprocessamento.</td>
# </tr>
# </table><br/><br/>

# %% [markdown]
# ### 1.1 Importando o Dataset

# %%
data = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado_final.csv')

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 1.2. Mostrando a cabeça do Dataframe

# %%
# 5 primeiras linhas/instâncias
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
# 10 primeiras linhas/instâncias
data.head(10)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# ...

# %% [markdown]
# ### 1.3. Informações básicas do Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103392 entries, 0 to 103391
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  object
#  1   DATA FINAL                     103392 non-null  object
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
# ...

# %%
data2 = data.copy()
data2
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103392 entries, 0 to 103391
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  object
#  1   DATA FINAL                     103392 non-null  object
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
# ...

# %%
data2.loc[0, 'NÚMERO DE POSTOS PESQUISADOS'] = 'TESTE MUITO LEGAL'

# %%
data2.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO            TESTE MUITO LEGAL              R$/l
# 1  ETANOL HIDRATADO                          387              R$/l
# 2  ETANOL HIDRATADO                          192              R$/l
# 3  ETANOL HIDRATADO                          162              R$/l
# 4  ETANOL HIDRATADO                          103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103392 entries, 0 to 103391
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  object
#  1   DATA FINAL                     103392 non-null  object
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  object
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
# ...

# %% [markdown]
# #### **Estatísticas Descritivas Gerais**
# PS: considerando _todo o dataset_.

# %%
data.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# ...

# %% [markdown]
# <h2>2. Extraindo Estatísticas Descritivas Mais Específicas</h2>
# <hr/>

# %% [markdown]
# ### 2.1 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
df = data.query('ESTADO == "SAO PAULO" and ANO == 2018 and PRODUTO == "GASOLINA COMUM"')

# %%
df.head()
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92610   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92755   2018-01-28  2018-02-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92901   2018-02-04  2018-02-10  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 92319                          1641              R$/l                3.988
# 92465                          1648              R$/l                4.002
# 92610                          1648              R$/l                4.006
# 92755                          1644              R$/l                4.019
# 92901                          1646              R$/l                4.004
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %% [markdown]
# #### **Estatísticas Descritivas**

# %%
df.describe()
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                     52.000000            52.000000
# mean                    1610.211538             4.202769
# std                      213.627432             0.180672
# min                      102.000000             3.970000
# 25%                     1639.000000             4.008000
# 50%                     1642.000000             4.202000
# 75%                     1644.000000             4.336250
# max                     1649.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count              52.000000             52.000000             52.000000
# mean                0.175500              3.671500              4.975750
# std                 0.017955              0.163808              0.211198
# min                 0.150000              3.369000              4.499000
# 25%                 0.159750              3.499000              4.899000
# ...

# %%
df['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    52.000000
# mean      4.202769
# std       0.180672
# min       3.970000
# 25%       4.008000
# 50%       4.202000
# 75%       4.336250
# max       4.512000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
df['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count            52.000000
# mean              4.202769
# std               0.180672
# min               3.970000
# 25%               4.008000
# 50%               4.202000
# 75%               4.336250
# max               4.512000

# %% [markdown]
# #### **Tendência Central dos Preços**

# %% [markdown]
# ##### **Média**

# %%
print(f'O preço médio da Gasolina no Estado de São em 2018 foi de R$ {df["PREÇO MÉDIO REVENDA"].mean():.2f} ± {df["PREÇO MÉDIO REVENDA"].std():.2f}')
# Out:
# O preço médio da Gasolina no Estado de São em 2018 foi de R$ 4.20 ± 0.18

# %% [markdown]
# ##### **Mediana**

# %%
print(f'A mediana do preço da Gasolina Comum no estado de SP em 2018 é R$ {df["PREÇO MÉDIO REVENDA"].median():.2f}')
# Out:
# A mediana do preço da Gasolina Comum no estado de SP em 2018 é R$ 4.20

# %% [markdown]
# ### **Variabilidade**

# %% [markdown]
# #### Histograma com número de bins padrão:

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=df, x='PREÇO MÉDIO REVENDA')

plt.title('Histograma dos Preços da Gasolina do Estado de SP em 2018')
plt.xlabel('Preço da Gasolina (R$)')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %% [markdown]
# #### Alterando o **número de bins** do Histograma.

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=df, x='PREÇO MÉDIO REVENDA', bins=10)

plt.title('Histograma dos Preços da Gasolina do Estado de SP em 2018')
plt.xlabel('Preço da Gasolina (R$)')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %% [markdown]
# #### Checando a variabilidade usando **BoxPlots**

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(data=df, x='PREÇO MÉDIO REVENDA')

plt.title('Boxplot da Gasolina de SP em 2018')
plt.xlabel('Preço da Gasolina (R$)')
# Out:
# Text(0.5, 0, 'Preço da Gasolina (R$)')

# %% [markdown]
# #### Checando a variabilidade usando **Violin Plot**

# %%
plt.figure(figsize=(10, 6))

sns.violinplot(data=df, x='PREÇO MÉDIO REVENDA')

plt.title('Boxplot da Gasolina de SP em 2018')
plt.xlabel('Preço da Gasolina (R$)')
# Out:
# Text(0.5, 0, 'Preço da Gasolina (R$)')

# %% [markdown]
# ### 2.2 Há uma correlação linear entre os Preços de Distribuição e Preços de Revenda dos combustíveis?

# %% [markdown]
# Consideraremos todo o dataset para tal consulta.

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
# mostra a correlação de todo mundo com todo mundo
data.corr()
# Out:
#                                NÚMERO DE POSTOS PESQUISADOS  \
# NÚMERO DE POSTOS PESQUISADOS                       1.000000
# PREÇO MÉDIO REVENDA                                0.001806
# DESVIO PADRÃO REVENDA                              0.032180
# PREÇO MÍNIMO REVENDA                              -0.017289
# PREÇO MÁXIMO REVENDA                               0.015176
# MARGEM MÉDIA REVENDA                               0.018958
# COEF DE VARIAÇÃO REVENDA                           0.143625
# PREÇO MÉDIO DISTRIBUIÇÃO                          -0.003749
# DESVIO PADRÃO DISTRIBUIÇÃO                         0.050305
# PREÇO MÍNIMO DISTRIBUIÇÃO                         -0.029446
# PREÇO MÁXIMO DISTRIBUIÇÃO                          0.024259
# COEF DE VARIAÇÃO DISTRIBUIÇÃO                      0.036472
# MÊS                                               -0.014279
# ANO                                               -0.146391
#
# ...

# %%
# filtrando apenas as colunas/variáveis de interesse
df = data[['PREÇO MÉDIO DISTRIBUIÇÃO', 'PREÇO MÉDIO REVENDA']]
df
# Out:
#         PREÇO MÉDIO DISTRIBUIÇÃO  PREÇO MÉDIO REVENDA
# 0                          0.825                1.288
# 1                          0.763                1.162
# 2                          0.970                1.389
# 3                          0.830                1.262
# 4                          0.941                1.181
# ...                          ...                  ...
# 103387                     2.756                3.574
# 103388                     2.451                3.401
# 103389                     1.998                2.912
# 103390                     2.374                3.020
# 103391                     2.518                3.697
#
# [103392 rows x 2 columns]

# %%
df.corr()
# Out:
#                           PREÇO MÉDIO DISTRIBUIÇÃO  PREÇO MÉDIO REVENDA
# PREÇO MÉDIO DISTRIBUIÇÃO                  1.000000             0.994852
# PREÇO MÉDIO REVENDA                       0.994852             1.000000

# %%
sns.jointplot(data=df, x='PREÇO MÉDIO DISTRIBUIÇÃO', y='PREÇO MÉDIO REVENDA', height=10)

# %% [markdown]
# <h2>3. Exercícios</h2>
# <hr/>

# %% [markdown]
# ### 3.1 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %% [markdown]
# ### 3.2 Como os preços da Gasolina Comum e Etanol variaram no estado de SP ao longo dos anos?
# Dica: use o _lineplot_ (gráfico de linha).

# %% [markdown]
# ### 3.3 Qual a correlação entre o Preço de Distribuição e de Revenda da Gasolina Comum?
